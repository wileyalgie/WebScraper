# %%
import vistaService as vista
import pandas as pd

# %%
search = 'monitor'

list_df = vista.get_completed_list_view_df(search)
grid_df = vista.get_completed_grid_view_df(search)

list_df.set_index('Id').join(grid_df.set_index('Id'), lsuffix='_list')
# Out:
#              Lot_list                                         Title_list  \
# Id
# (110549182,)   Lot 50  DisplayPort to HDMI Cable 3.3ft, iVANKY Uni-Di...
# (110467830,)  Lot 226  Computer Speakers, 6W PC Powered Speakers USB ...
# (110500671,)  Lot 412  PixelRo Universal Blue Light Blocking Screen P...
# (110315878,)    Lot 2  Lenovo Q27h-10 27-Inch Monitor, QHD (2560 x 14...
# (110316572,)    Lot 6  Dell 27 LED Backlit LCD Monitor SE2719H IPS Fu...
# ...               ...                                                ...
# (104593191,)    Lot 2  Z-Edge 27-inch Curved Gaming Monitor, Full HD ...
# (104593637,)    Lot 4  Samsung FT45 Series 24-Inch FHD 1080p Computer...
# (104594088,)    Lot 6  SAMSUNG Odyssey G3 Series 24-Inch FHD 1080p Ga...
# (104594534,)    Lot 8  SAMSUNG T350 Series 22-Inch FHD 1080p Computer...
# (104626834,)  Lot 157  ASUS TUF Gaming VG279QL1A 27” HDR Gaming Monit...
#
#              Retail_Price                                          Condition  \
# Id
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [(Id,), (Lot,), (Title,), (Retail_Price,), (Condition,), (Current_Price,)]
# Index: []

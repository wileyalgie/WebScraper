# %%
import vistaService as vista
import pandas as pd

pd.set_option('display.max_colwidth', None)

# %%
search = 'portable monitor'

df = vista.get_completed_search_list(search)

# Filter down the list more
df['_validsearch'] = df['Title'].str.contains(r'^(?=.*portable)(?=.*monitor)',False)
df = df.loc[df['_validsearch']==True]
del df['_validsearch']
print('Filtered Down List: ', df.shape[0])
# Out:
# Completed List View:  284
# Completed Grid View:  284
# Completed Merged Search List:  284
# Filtered Down List:  235

# %%
search = 'portable monitor'

df = vista.get_active_search_list(search)
# Out:
# Active Grid View:  13

# %%
df
# Out:
#            Id      Lot  \
# 0   217248233    Lot 1
# 1   217249407    Lot 7
# 2   217249939   Lot 10
# 3   217250820   Lot 15
# 4   217251018   Lot 16
# 5   217253906   Lot 31
# 6   217254498   Lot 34
# 7   217255396   Lot 39
# 8   217333712  Lot 448
# 9   217343629  Lot 498
# 10  217385293  Lot 720
# 11  217385492  Lot 721
# 12  217386109  Lot 725
#
#                                                                                Title  \
# 0   ASUS ZenScreen 15.6” 1080P Portable USB Monitor (MB166C) - Full HD, IPS, USB Typ
# 1   ASUS ZenScreen 15.6” 1080P Portable USB Monitor (MB166C) - Full HD, IPS, USB Typ
# 2    FICIHP Triple Screen Laptop Monitor, 12’’ Portable Monitor for Laptop 1080P FHD
# 3   InnoView Portable Monitor, Ultra Slim Portable Monitor for Laptop HDMI USB C, 15
# 4    ZSCMALLS Portable Monitor 15.6 Inch Full HD Computer Display USB C Dual Monitor
# 5   ASUS ZenScreen 15.6” 1080P Portable USB Monitor (MB166C) - Full HD, IPS, USB Typ
# ...
